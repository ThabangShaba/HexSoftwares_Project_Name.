# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/thaba/OneDrive/Documentos/Hex Software/tested.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # Basic statistical analysis

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.shape
# Out:
# (418, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
data['SibSp'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 8], dtype=int64)

# %%
#renaming columns

data = data.rename(columns= {'PassengerId' : 'Passenger_ID',
                                   'Pclass' : 'P_Class'})
data
# Out:
#      Passenger_ID  Survived  P_Class  \
# 0             892         0        3
# 1             893         1        3
# 2             894         0        2
# 3             895         0        3
# 4             896         1        3
# ..            ...       ...      ...
# 413          1305         0        3
# 414          1306         1        1
# 415          1307         0        3
# 416          1308         0        3
# 417          1309         0        3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# correlation matrix
data_numeric = data.select_dtypes(include=['number'])
data_corr = data_numeric.corr()
data_corr
# Out:
#               Passenger_ID  Survived   P_Class       Age     SibSp     Parch  \
# Passenger_ID      1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived         -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# P_Class          -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age              -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp             0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch             0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare              0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                   Fare
# Passenger_ID  0.008211
# Survived      0.191514
# P_Class      -0.577147
# Age           0.337932
# SibSp         0.171539
# Parch         0.230046
# Fare          1.000000

# %% [markdown]
# # Cleaning the data

# %%
data.isnull().sum()
# Out:
# Passenger_ID      0
# Survived          0
# P_Class           0
# Name              0
# Sex               0
# Age              86
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin           327
# Embarked          0
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#      Passenger_ID  Survived  P_Class  \
# 0             892         0        3
# 1             893         1        3
# 2             894         0        2
# 3             895         0        3
# 4             896         1        3
# ..            ...       ...      ...
# 413          1305         0        3
# 414          1306         1        1
# 415          1307         0        3
# 416          1308         0        3
# 417          1309         0        3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# dropping unwanted columns
data_dp = data.drop(columns= ['Embarked', 'Cabin'])
data_dp
# Out:
#      Passenger_ID  Survived  P_Class  \
# 0             892         0        3
# 1             893         1        3
# 2             894         0        2
# 3             895         0        3
# 4             896         1        3
# ..            ...       ...      ...
# 413          1305         0        3
# 414          1306         1        1
# 415          1307         0        3
# 416          1308         0        3
# 417          1309         0        3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# filling missing values with the mean

data_dp['Age'] = data_dp['Age'].fillna(data_dp['Age'].mean()).round().astype(int)

# %%
data_dp
# Out:
#      Passenger_ID  Survived  P_Class  \
# 0             892         0        3
# 1             893         1        3
# 2             894         0        2
# 3             895         0        3
# 4             896         1        3
# ..            ...       ...      ...
# 413          1305         0        3
# 414          1306         1        1
# 415          1307         0        3
# 416          1308         0        3
# 417          1309         0        3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                       Myles, Mr. Thomas Francis    male   62      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# ...

# %%
data_dp.isnull().sum()
# Out:
# Passenger_ID    0
# Survived        0
# P_Class         0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# dtype: int64

# %%
# changing format in name column to initial, first name then last name

def format_name(name):
    parts = name.split()
    
    if len(parts) >= 2:
        initials = "".join([p[0].upper() + "." for p in parts[:-1]])  
        first_name = parts[0].title()  
        last_name = parts[-1].title()  
        return f"{initials} {first_name} {last_name}"
    return name  


data_dp['Name'] = data_dp['Name'].apply(format_name)


data_dp
# Out:
#      Passenger_ID  Survived  P_Class                        Name     Sex  Age  \
# 0             892         0        3             K.K. K.M. James    male   34
# 1             893         1        3        W.W. W.M.J.(. Needs)  female   47
# 2             894         0        2         M.M. M.M.T. Francis    male   62
# 3             895         0        3            W.W. W.M. Albert    male   27
# 4             896         1        3  H.H. H.M.A.(.E. Lindqvist)  female   22
# ..            ...       ...      ...                         ...     ...  ...
# 413          1305         0        3             S.S. S.M. Woolf    male   30
# 414          1306         1        1       O.O. O.Y.O.D. Fermina  female   39
# 415          1307         0        3       S.S. S.M.S. Sivertsen    male   38
# 416          1308         0        3         W.W. W.M. Frederick    male   30
# 417          1309         0        3               P.P. P.M.M. J    male   30
#
# ...

# %%
# Remove full stops inside brackets
data_dp['Name'] = data_dp['Name'].str.replace(r'\((.*?)\.', r'(\1', regex=True)
data_dp
# Out:
#      Passenger_ID  Survived  P_Class                       Name     Sex  Age  \
# 0             892         0        3            K.K. K.M. James    male   34
# 1             893         1        3        W.W. W.M.J.( Needs)  female   47
# 2             894         0        2        M.M. M.M.T. Francis    male   62
# 3             895         0        3           W.W. W.M. Albert    male   27
# 4             896         1        3  H.H. H.M.A.(E. Lindqvist)  female   22
# ..            ...       ...      ...                        ...     ...  ...
# 413          1305         0        3            S.S. S.M. Woolf    male   30
# 414          1306         1        1      O.O. O.Y.O.D. Fermina  female   39
# 415          1307         0        3      S.S. S.M.S. Sivertsen    male   38
# 416          1308         0        3        W.W. W.M. Frederick    male   30
# 417          1309         0        3              P.P. P.M.M. J    male   30
#
# ...

# %%
# removing brackets in name column

data_dp['Name'] = data_dp['Name'].str.replace(r'\(.*\)', '', regex=True)
data_dp
# Out:
#      Passenger_ID  Survived  P_Class                   Name     Sex  Age  \
# 0             892         0        3        K.K. K.M. James    male   34
# 1             893         1        3            W.W. W.M.J.  female   47
# 2             894         0        2    M.M. M.M.T. Francis    male   62
# 3             895         0        3       W.W. W.M. Albert    male   27
# 4             896         1        3            H.H. H.M.A.  female   22
# ..            ...       ...      ...                    ...     ...  ...
# 413          1305         0        3        S.S. S.M. Woolf    male   30
# 414          1306         1        1  O.O. O.Y.O.D. Fermina  female   39
# 415          1307         0        3  S.S. S.M.S. Sivertsen    male   38
# 416          1308         0        3    W.W. W.M. Frederick    male   30
# 417          1309         0        3          P.P. P.M.M. J    male   30
#
#      SibSp  Parch              Ticket      Fare
# ...

# %%
# Adding commas where its missing in name column

def add_comma_if_missing(name):
    if ',' not in name:  
        parts = name.split()
        if len(parts) >= 2:
            return f"{parts[0]}, {parts[-1]}"  
    return name  

data_dp['Name'] = data_dp['Name'].apply(add_comma_if_missing)
data_dp
# Out:
#      Passenger_ID  Survived  P_Class             Name     Sex  Age  SibSp  \
# 0             892         0        3      K.K., James    male   34      0
# 1             893         1        3     W.W., W.M.J.  female   47      1
# 2             894         0        2    M.M., Francis    male   62      0
# 3             895         0        3     W.W., Albert    male   27      0
# 4             896         1        3     H.H., H.M.A.  female   22      1
# ..            ...       ...      ...              ...     ...  ...    ...
# 413          1305         0        3      S.S., Woolf    male   30      0
# 414          1306         1        1    O.O., Fermina  female   39      0
# 415          1307         0        3  S.S., Sivertsen    male   38      0
# 416          1308         0        3  W.W., Frederick    male   30      0
# 417          1309         0        3          P.P., J    male   30      1
#
#      Parch              Ticket      Fare
# ...

# %%
#check the type of errors or issues in a column
def check_errors_in_column(column):
    errors = {
        'NaN values': column.isna().sum(),
        'Non-string values': column[~column.apply(lambda x: isinstance(x, str))].count(),
        'Empty strings': (column == '').sum(),
        'Invalid numbers': column.apply(lambda x: isinstance(x, str) and x.replace('.', '', 1).isdigit()).sum(),
    }
    return errors

data_errors = check_errors_in_column(data_dp['Fare'])

print(data_errors)
# Out:
# {'NaN values': 1, 'Non-string values': 417, 'Empty strings': 0, 'Invalid numbers': 0}

# %%
# filling missinng values in fare variables with the median

data_dp['Fare']= data_dp['Fare'].fillna(data_dp['Fare'].median())
print(data_dp)
# Out:
#      Passenger_ID  Survived  P_Class             Name     Sex  Age  SibSp  \
# 0             892         0        3      K.K., James    male   34      0
# 1             893         1        3     W.W., W.M.J.  female   47      1
# 2             894         0        2    M.M., Francis    male   62      0
# 3             895         0        3     W.W., Albert    male   27      0
# 4             896         1        3     H.H., H.M.A.  female   22      1
# ..            ...       ...      ...              ...     ...  ...    ...
# 413          1305         0        3      S.S., Woolf    male   30      0
# 414          1306         1        1    O.O., Fermina  female   39      0
# 415          1307         0        3  S.S., Sivertsen    male   38      0
# 416          1308         0        3  W.W., Frederick    male   30      0
# 417          1309         0        3          P.P., J    male   30      1
#
#      Parch              Ticket      Fare
# ...

# %%
#check for anymore null in the dataset

data_dp.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Data visualisation

# %%
import matplotlib.pyplot as plt

# %%
# correlation of numeric columns

data_dp_numeric = data_dp.select_dtypes(include=['number'])

data_dp_corr = data_dp_numeric.corr()

print(data_dp_corr)
# Out:
#               Passenger_ID  Survived   P_Class       Age     SibSp     Parch  \
# Passenger_ID      1.000000 -0.023245 -0.026751 -0.030390  0.003818  0.043080
# Survived         -0.023245  1.000000 -0.108615  0.001362  0.099943  0.159120
# P_Class          -0.026751 -0.108615  1.000000 -0.443812  0.001087  0.018721
# Age              -0.030390  0.001362 -0.443812  1.000000 -0.079075 -0.044669
# SibSp             0.003818  0.099943  0.001087 -0.079075  1.000000  0.306895
# Parch             0.043080  0.159120  0.018721 -0.044669  0.306895  1.000000
# Fare              0.008633  0.192036 -0.577313  0.326319  0.171912  0.230325
#
#                   Fare
# Passenger_ID  0.008633
# Survived      0.192036
# P_Class      -0.577313
# Age           0.326319
# SibSp         0.171912
# Parch         0.230325
# Fare          1.000000

# %%
data_dp
# Out:
#      Passenger_ID  Survived  P_Class             Name     Sex  Age  SibSp  \
# 0             892         0        3      K.K., James    male   34      0
# 1             893         1        3     W.W., W.M.J.  female   47      1
# 2             894         0        2    M.M., Francis    male   62      0
# 3             895         0        3     W.W., Albert    male   27      0
# 4             896         1        3     H.H., H.M.A.  female   22      1
# ..            ...       ...      ...              ...     ...  ...    ...
# 413          1305         0        3      S.S., Woolf    male   30      0
# 414          1306         1        1    O.O., Fermina  female   39      0
# 415          1307         0        3  S.S., Sivertsen    male   38      0
# 416          1308         0        3  W.W., Frederick    male   30      0
# 417          1309         0        3          P.P., J    male   30      1
#
#      Parch              Ticket      Fare
# ...

# %%
# heatmap for correlation

sns.heatmap(data_dp_corr, xticklabels=data_dp_corr.columns, yticklabels=data_dp_corr.columns, annot=True)
plt.show()

# %%
# scatterplot for all the variables in the dataset

sns.pairplot(data_dp)

# %%
# scatterplot of Age vs Fare by the gender

sns.scatterplot(x= 'Age', y= 'Fare', hue='Sex', data=data_dp)

plt.title("Scatter Plot of Age vs Fare (Colored by Sex)")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Fare (Colored by Sex)')

# %%
# The histogram for Age

sns.histplot(data=data_dp, x='Age', kde=True)
plt.title("The distribution of Age")
# Out:
# Text(0.5, 1.0, 'The distribution of Age')

# %%
#Boxplot for survived passengers

sns.catplot(x='Survived', kind= 'box', data= data_dp)
plt.title("Distribution of Survived Passengers")
# Out:
# Text(0.5, 1.0, 'Distribution of Survived Passengers')

# %%
#Boxplot for fare variable

sns.catplot(x='Fare', kind= 'box', data= data_dp)
plt.title("Distribution of Fare of Passengers")
# Out:
# Text(0.5, 1.0, 'Distribution of Fare of Passengers')

# %% [markdown]
# # Completed
